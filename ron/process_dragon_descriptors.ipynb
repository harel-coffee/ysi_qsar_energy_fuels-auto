# %%
import pandas as pd

# %%
mol_df = pd.read_csv('ron_data_smiles.csv')
mol_df.to_pickle('../ysi_utils/data/ron.p')

# %%
dragon_descriptors = pd.read_csv('ron_dragon_output.tsv', sep='\t', index_col=0)
dragon_descriptors.index = mol_df.SMILES
dragon_descriptors.drop('NAME', 1, inplace=True)

dragon_descriptors.to_pickle('../ysi_utils/descriptors/dragon_ron.p')

# %%
dragon_descriptors.head()
# Out:
#                    MW    AMW      Sv      Se      Sp      Si     Mv     Me  \
# SMILES
# C=CCCCC         84.18  4.677   9.161  17.302  10.568  20.491  0.509  0.961
# CC(C)=CC(C)C    98.21  4.677  10.688  20.185  12.330  23.906  0.509  0.961
# Cc1ccc(C)o1     96.14  6.409   8.822  14.862   9.500  16.870  0.588  0.991
# CC(C)CCCC(C)C  128.29  4.424  14.268  27.836  16.614  33.152  0.492  0.960
# CCC(C)O         74.14  4.943   7.349  14.745   8.262  17.285  0.490  0.983
#
#                   Mp     Mi      ...       CATS3D_10_LL  CATS3D_11_LL  \
# SMILES                           ...
# C=CCCCC        0.587  1.138      ...                  0             0
# CC(C)=CC(C)C   0.587  1.138      ...                  0             0
# Cc1ccc(C)o1    0.633  1.125      ...                  0             0
# CC(C)CCCC(C)C  0.573  1.143      ...                  0             0
# CCC(C)O        0.551  1.152      ...                  0             0
#
# ...
